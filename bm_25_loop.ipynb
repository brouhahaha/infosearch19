# %% [markdown]
# ## Лекция 2  BM5

# %% [markdown]
# ## Функция ранжирования bm25

# %% [markdown]
# Для обратного индекса есть общепринятая формула для ранжирования *Okapi best match 25* ([Okapi BM25](https://ru.wikipedia.org/wiki/Okapi_BM25)).
# Пусть дан запрос $Q$, содержащий слова  $q_1, ... , q_n$, тогда функция BM25 даёт следующую оценку релевантности документа $D$ запросу $Q$:
#
# $$ score(D, Q) = \sum_{i}^{n} \text{IDF}(q_i)*\frac{TF(q_i,D)*(k+1)}{TF(q_i,D)+k(1-b+b\frac{l(d)}{avgdl})} $$
# где
# >$TF(q_i,D)$ - частота слова $q_i$ в документе $D$
# $l(d)$ - длина документа (количество слов в нём)
# *avgdl* — средняя длина документа в коллекции
# $k$ и $b$ — свободные коэффициенты, обычно их выбирают как $k$=2.0 и $b$=0.75
# $$$$
# $\text{IDF}(q_i)$ - это модернизированная версия IDF:
# $$\text{IDF}(q_i) = \log\frac{N-n(q_i)+0.5}{n(q_i)+0.5},$$
# >> где $N$ - общее количество документов в коллекции
# $n(q_i)$ — количество документов, содержащих $q_i$

# %% [markdown]
# ### __Задача 1__:
# Напишите два поисковика на *BM25*. Один через подсчет метрики по формуле для каждой пары слово-документ, второй через умножение матрицы на вектор.
#
# Сравните время работы поиска на 100к запросах. В качестве корпуса возьмем
# [Quora question pairs](https://www.kaggle.com/loopdigga/quora-question-pairs-russian).

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
import re
import numpy as np
from math import log
import random

import nltk 
from nltk.text import Text 
import pymorphy2 as pm2 
pmm = pm2.MorphAnalyzer() 

nltk.download("stopwords") 
#--------# 
from nltk.corpus import stopwords 
russian_stopwords = stopwords.words("russian")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Maria\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import csv

with open('quora_question_pairs_rus.csv', 'r', encoding = 'utf-8') as f:  
    spamreader = csv.reader(f)
    data = [row[1:] for row in spamreader][1:]
    corpus = [row[1] for row in data]
    
corpus
# Out:
# ['что произойдет, если правительство Индии украдет кохинор кох-и-ноор-алмаз назад',
#  'как повысить скорость интернета путем взлома через dns',
#  'найти остаток, когда математика 23 ^ 24 математика разделена на 24 23',
#  'какая рыба выживет в соленой воде',
#  'Я тройная луна-козерог и восхождение в козероге, что это говорит обо мне',
#  'что делает детей активными и далеки от телефонных и видеоигр',
#  'что я должен делать, чтобы быть великим геологом?',
#  'когда вы используете вместо',
#  'как я могу взломать motorola dcx3400 для бесплатного интернета',
#  'что некоторые технические специалисты могут рассказать о долговечности и надежности ноутбуков и их компонентов',
#  'как я могу увидеть все мои комментарии к YouTube',
#  'как вы можете легко научиться физике',
#  'какой был ваш первый сексуальный опыт',
#  'каковы законы об изменении вашего статуса от студенческой визы до зеленой карты в нас, как они сравниваются с иммиграционными законами в Японии',
#  'как президентство козыря повлияет на учеников в настоящее время в нас или планирует учиться у нас',
#  'что означает манипуляция',
#  'как ребята чувствуют себя после отказа от девушки',
#  'почему люди задают вопросы о quora, на которые можно легко ответить google',
#  'который является лучшим институтом цифрового маркетинга в Пуне',
#  'почему ракеты и ускорители окрашены в белый цвет',
#  'что я могу сделать, чтобы не ревновать кого-то',
#  'какой вопрос я должен задать на quora',
#  'где я могу найти диаграмму преобразования для cc to horsepower',
#  'сколько раз в день перекрывают руки часы',
#  'каковы некоторые советы о том, чтобы сделать это через процесс собеседования на дому в медицинской медицине',
#  'какова структура веб-приложений',
#  'как спорт вносит свой вклад в общество',
#  'лучший способ попросить деньги в Интернете',
#  'как следует знать, что он полностью готовится к заключительному экзамену',
#  'что вы делаете, хотя зная лучше',
#  'как я могу держать нос от душного в ночное время',
#  'какая игра престола злодея вам больше всего понравится быть во власти',
#  'как определяется средняя скорость молекул газа',
#  'какой лучший веб-сайт путешествия',
#  'была инициатива по контролю за оружием, чтобы забрать оружие, которое уже есть у людей',
#  'Я 19-летний парень, как я могу стать миллиардером в ближайшие 10 лет',
#  'моя подруга сказала, что мы должны это прекратить, потому что она смущена своими чувствами ко мне, я пожелал ей хорошо и отключился, если я позвоню ей и спрошу ее, хочет ли она вернуться',
#  'как я готовлюсь к государственной службе',
#  'почему воздушное судно прекратило использовать крылья с изменяемой разверткой, например, на f - 14',
#  'приседания делают мои ноги более толстыми',
#  'когда я могу ожидать знакомой почты подтверждения',
#  'могу ли я делать 30 000 ежемесячных торгов',
#  'скучает хорошо для ребенка',
#  'какие университеты делают bg-продукты, набирают новых выпускников из того, что делают майоры',
#  'как мы можем увеличить количество последователей instagram',
#  'у quora есть лимит символов для описания профиля',
#  'который больше всего пострадал от распада мальчика или девочку',
#  'какие продукты из сырой нефти',
#  'как подружиться',
#  'как онлайн-программа для начинающих по программе rbi grade b',
#  'как вы можете играть на Blu-ray DVD на обычном DVD-плеере',
#  'аэродинамически, что происходит, когда винт вращается',
#  'какое самое вкусное блюдо вы когда-либо ели и почему',
#  'почему я не могу сделать домашнее задание',
#  'вы подаете заявку на такие программы, как rsi, когда вы становитесь старшим',
#  'это мой парень, который лжет о своих истинных чувствах к своему другу, и его тайно привлекает к ней',
#  'какие из лучших рэп-песен',
#  'Я не могу вспомнить мой пароль gmail или мой адрес электронной почты для восстановления, как я могу восстановить свой адрес электронной почты',
#  'как я изучаю французский полы',
#  'это надежные торренты',
#  'что вызывает темное кольцо вокруг радужки, как его следует лечить',
#  'насколько плоха новая книга jk rowling',
#  'почему я всегда впадаю в депрессию',
#  'где я могу найти американскую базу данных семейного офиса',
#  'как я узнаю компьютерный язык, например java',
#  'какая самая важная книга, которую вы когда-либо читали',
#  'возможно ли хранить энергию молнии',
#  'что такое тестирование производительности',
#  'есть ли люди, которые искренне пользуются салатом без приправы',
#  'каковы различные типы иммунитета в нашем организме',
#  'что такое нарциссическое расстройство личности',
#  'как я могу научиться свободно говорить по-английски',
#  'что такое номер телефона службы поддержки клиентов quickbooks usa',
#  'который является самым богатым игроком всех времен и как я могу достичь его уровня в качестве игрока',
#  'делать пули быстрее, чем скорость звука при выстреле из пистолета, если это невозможно, если они делают то, что пистолет и сколько разрушений происходит',
#  'предотвращается рак молочной железы',
#  'как я могу узнать, кто вошел в мою учетную запись gmail, указав свой IP-адрес или имя устройства',
#  'какие-то разные способы заработать деньги в Интернете, исключая продажи вещей',
#  'Какова цель жизни, что на самом деле является жизнью',
#  'почему Индия не применяет модель burma-rohingya для депортации незаконных бангладеш',
#  'насколько важно быть первым, кто пожелает кому-то счастливого дня рождения',
#  'Я хочу сделать туристический видеоролик о путешествиях для Индии и Новой Зеландии, сколько это будет стоить',
#  'почему технические сотрудники так сильно презирают продавцов',
#  'каковы некоторые высокооплачиваемые рабочие места для более свежего с технологией m в области биотехнологии',
#  'может увеличить рост после 25',
#  'каковы были основные последствия землетрясения в Камбодже и как эти эффекты сравниваются с землетрясением в Вальпараисо в 1822 году',
#  'в чем разница между честным и искренним',
#  'который является лучшим игровым ноутбуком под rs 60000',
#  'каков ваш обзор следующего воина: полигоны - часть 5',
#  'какую книгу я должен выбрать для справки для физики и химии класса 11 cbse board',
#  'национальный институт технологии karnataka nitk surathkal: к выпускной части: какие уроки вы хотели бы дать своим юниорам, прежде чем покинуть',
#  'какой лучший романтический фильм вы когда-либо видели',
#  'что вызывает кошмары, которые кажутся реальными',
#  'каковы некоторые из основных влияний абстрактного экспрессионизма',
#  'как работают 3D-печать',
#  'которые являются известными людьми, которые посещали caltech',
#  'что такое хоркрукс',
#  'каково общее требование стать менеджером продукта или менеджером программ в компании, основанной на продуктах',
#  'как я могу получить skype для работы на телефоне Android 4 1 1',
#  'будет ли ядерная война между Индией и Пакистаном',
#  'как реагировал Рональд Рейган 911',
#  'как могли конфедераты, возможно, победить профсоюзные силы в Gettysburg во время американской гражданской войны',
#  'которые являются одними из лучших художественных романов',
#  'что я должен делать, если я забыл свой пароль по электронной почте',
#  'как демонизация может повлиять на gdp Индии как в краткосрочной, так и в долгосрочной перспективе',
#  'может быть взломан',
#  'в чем разница между любовью и жалостью',
#  'насколько конкурентоспособным является процесс найма в банке s t',
#  'каково распределение трафика между результатами поиска Google, например, 1 против 2 в рейтинге первой страницы против второй страницы',
#  'где можно посмотреть sarrainodu с субтитрами',
#  'почему США - самая могущественная страна мира',
#  'что лучше для боли в пояснице: жара или лед',
#  'как вы думаете о китайской кухне?',
#  'хуже ли использовать кого-то или быть материалистичным',
#  'почему мы плачем',
#  'почему девочки-подростки и женщины вообще позволяют своим бойфрендам снимать обнаженные фотографии из них в этот день и в цифровой век',
#  'как winston и julia отличаются в романе 1984, как они похожи',
#  'какие существуют разумные технологии, которые большинство людей не знают о',
#  'самая дешевая зубная паста',
#  'как я могу задать вопрос, не указывая, как нужно улучшить',
#  'если каждое государство США объявит войну друг другу, которая выиграет',
#  'какой минерал может удерживать наибольший электрический заряд',
#  'какая величайшая тайна всех времен',
#  'как я перевыполняю набор данных мультиклассического дисбаланса',
#  'почему китайская поддержка masood azhar',
#  'в чем смысл будущего',
#  'как витамин c вызывает выкидыш',
#  'когда мы получим письмо с призывом после того, как мы получим письмо о намерениях в призыве asahi india glass recruitment',
#  'как я могу получить доступ к google com из Индии',
#  'что такое мантра Янтра',
#  'какой курс лучше в никмаре',
#  'как зарегистрировать домен',
#  'почему меня привлекают пожилые мужчины',
#  'что является самым сильным шнуром кевлара',
#  'которые являются ронингами',
#  'имеет ли значение, является ли человечество злом или нет',
#  'каковы примеры пассивного переноса в клетках',
#  'если я брею свою голову в течение 2 лет, как я становлюсь лысым, а затем росли волосы, волосы будут такими же, как когда у меня есть или у меня больше волос',
#  'что такое жизнь после выхода на пенсию',
#  'Какова позиция Пакистана, обладающего оружием массового уничтожения северной кореей, поддерживает ли он dprk или против dprk',
#  'как я могу найти хорошего эскорта',
#  'Какая лучшая диета для растущего десятилетнего',
#  'черная дыра имеет конечную массу',
#  'каковы ваши взгляды на эту цитату моргана о расизме',
#  'В настоящее время uber предлагает новые варианты опционов на акции или rsus',
#  'есть хорошая оплата для сайтов отзывов там',
#  'сколько способов 12 яблок могут быть распределены среди 4 детей, так что каждый ребенок получает по меньшей мере 2 яблока',
#  'сколько в среднем стоило бы на видеоленту 2-часовую презентацию',
#  'я могу принять инъекцию бешенства после 1 дня укуса собаки',
#  'какова стандартная сумма отпуска для международного переселения',
#  'как ты перестаешь бояться всего',
#  'почему красный держит ключи в сезоне 4 оранжевого - это новый черный',
#  'в каком возрасте, как и где вы потеряли свою девственность',
#  'как я могу забыть свою жену',
#  'как можно было засмеяться, если он был убит императором палпатином',
#  'как вы загружаете фильмы на YouTube и монетизируете их, есть ли какие-либо проблемы с авторским правом',
#  'какой штатив я должен получить для своего canon 6d',
#  'как кво выглядит модератором',
#  'почему никто не отвечает на мои вопросы в кворе',
#  'какая смешная шутка всех времен',
#  'если я уйду из Норвей, могу ли я заплатить свою ипотеку моей учетной записью bsu, а затем продать свою квартиру, не заплатив налоговый вычет, который я получил за bsu',
#  'что американцы думают о объединенном королевстве',
#  'как я могу использовать твиттер для бизнеса',
#  'как я могу отправить деньги с моей учетной записи PayPal на свой счет в skrill, чтобы снять',
#  'который является лучшим наушниками под RS 1000',
#  'может ли правительственный служащий применять iec',
#  'что правильно: говорить или говорить с',
#  'какая лучшая область техники',
#  'почему эмоционально оскорбительные люди в моей жизни несколько бывших друзей друзей и прошлых коллег боссы были обидчиками, я их привлекаю',
#  'кажется, есть разница между моей недельной зарплатой и годовой зарплатой, которую мой работодатель согласился с тем, как это работает',
#  'почему в Керале так много христиан',
#  'как я могу говорить с большей ясностью и уверенностью',
#  'какой параллелизм мы можем сделать между богами индуистской мифологии греческой мифологии египетской мифологии и т. д.',
#  'я должен переключиться с spotify на яблочную музыку',
#  'какой лучший фонд с фиксированным доходом',
#  'каково это жить в k ln germany',
#  'кого вы считаете лучшим актером робер де ниро или аль-пасино',
#  'почему некоторые люди предпочитают жить с маленькой семьей',
#  'делать животных, кроме людей, целует',
#  'как я могу просмотреть удаленные instagram dms',
#  'как я перестаю быть зависимым от кого-то',
#  'я мог бы нанять двух частных следователей, а затем заставить их следовать друг за другом',
#  'как ускорители запуска дают вам финансирование',
#  'я не могу открыть quora через мой Wi-Fi-маршрутизатор, почему я могу получить доступ к нему только через мобильную сеть',
#  'каково было значение битвы соммы и как это сражение сравнивалось и контрастировало с битвой в Эр-Рияде',
#  'имеет какой-либо сотрудник по приему колледжа, публично публичный, читая эссе участника',
#  'что произойдет, если глазная медицина попадет в глаза',
#  'как я отказываюсь выбирать между разными вещами в моей жизни',
#  'не фанов, пожалуйста, но кто был истинным бэтменским христианским тюком или ben affleck',
#  'какой бизнес лучше начать в Хайдарабаде',
#  'как я перестаю быть притяжательным для человека, которого я люблю',
#  'который является отцом лорда кришны',
#  'какие курсы необходимо проводить вместе с курсом',
#  'как сделать снимок экрана на моем macbook pro, какие инструкции',
#  'каково это - работать с исполнительным рекрутером',
#  'почему люди собирают вещи',
#  'есть ли какие-нибудь фильмы на телевидении',
#  'как я могу свободно говорить по-китайски',
#  'каково будет воздействие отказа на 500 и 1000 рупий на рынке недвижимости',
#  'лучший способ стать миллиардером',
#  'почти две недели на prozac, почему я до сих пор чувствую себя антисоциальным и все еще не хочу участвовать в событиях, почему меняется мое социальное поведение и настроение ежедневно',
#  'каков наилучший способ начать робототехнику, которая является лучшей платой развития, на которой я могу начать работать над ней',
#  'каковы причины, по которым люди не любят хартин',
#  'почему всегда ожидалось, что женщина должна заботиться о домашнем хозяйстве детей и приготовлении пищи, особенно в индийской культуре, - эти виды деятельности несут ответственность только для женщин, почему мужчины не имеют равного участия в такой работе',
#  'атеизм - отсутствие веры в богов или утверждение, что бог не существует',
#  'что такое дом-дорси',
#  'у которого убийца имеет лучшие одежды в кредо убийцы',
#  'если принтеры cmyk создают черный цвет с помощью цветных чернил и только дополняют черными чернилами, почему магазины взимают больше за цветные отпечатки',
#  'почему творчество важно',
#  'если бы хартинский клинтон больше не мог служить демократическим кандидатом, как бы ее преемник был выбран',
#  'почему телефоны не имеют встроенной антенны fm',
#  'himalayan или duke ktm 200 для гастролей',
#  'каковы преимущества перечисления компании в nse',
#  'когда рисование становится забавным',
#  'является нейтронной звездой, состоящей только из нейтронов',
#  'достаточно 3 8 гпа, чтобы попасть в высшую школу',
#  'что такое торговля двоичными опционами',
#  'может ли человек, окончивший iims, как личность, и даже новые iims, такие как ranchi и trichy, когда-либо догоняют выпускников abc и получают подобный пакет',
#  'как я могу начать изучать информационную безопасность',
#  'могу я заработать деньги на quora',
#  'что такое puk для tf64simc4',
#  'как я могу найти работу в Японии',
#  'какова наилучшая настройка домашней беспроводной сети и ожидаемые скорости',
#  'когда лотерея достигнет джекпота в следующем миллиарде долларов',
#  'мне нужен автомобиль с четырьмя колесами, чтобы проехать весь путь по дороге к хане',
#  'как создать новый терминал и новую оболочку в linux с помощью программирования c',
#  'влияет ли когнитивный штамм на пищеварение',
#  'я сделал резервирование железной дороги, но получил его в списке ожидания tatkal, я получу возмещение, если я его отменим',
#  'что я могу сделать, чтобы сделать мир лучше',
#  'который является лучшей лигой лиги чемпионов легенд',
#  'сколько литров воды я должен выпить, если я буду работать 5000 мс ежедневно',
#  'откуда берется вода из великих озер и как эти дикие животные озера сравниваются с озером como',
#  'как я могу заказать ronda rousey для просмотра в фильме для взрослых',
#  'теперь сторонники козыря ожидают, что президент выполнит свои обещания, которые он так решительно продал на',
#  'почему мы заботимся о других мнениях и о том, что другие думают о нас',
#  'как я горжусь тренировать своего двухмесячного лабрадора',
#  'какой лучший способ прыгать с веревкой',
#  'какая серия тестов является наилучшей для потока информационных технологий ворот',
#  'какая математика требует полного новичка, чтобы понять алгоритмы компьютерного программирования, какие книги по алгоритмам подходят для полного новичка',
#  'каков характер корги - хриплый микс',
#  'сколько четырехзначных чисел можно сформировать, используя 0 1 2 3 4 5 6 и 7, сколько из них составляет от 4000 до 6000',
#  'в изюминке на солнце, почему walter и beneatha спорят',
#  'что является признаком ультра умных людей, скрывающих свой интеллект',
#  'если энергия не сохраняется в расширяющейся Вселенной, потенциальная энергия бесконечна, энергия, которая может быть создана, бесконечна',
#  'каковы хорошие способы написания и публикации книги',
#  'кто нарушит блумберг',
#  'символ вспышки dc: как быстро вспышка может мигать',
#  'как я могу лучше всего инвестировать 5000 в течение следующих 6 месяцев',
#  'что такое gst bill и как именно это повлияет на простых людей',
#  'Я не помню свой пароль для своей учетной записи gmail, как я могу восстановить свою учетную запись',
#  'как я могу точно диагностировать и лечить психическое заболевание',
#  'это нормально, если 14-летняя девочка будет плевать кровью',
#  'какие хорошие качества лидера',
#  'какая именно разница между морем и заливом',
#  'может нарэндра modi стать премьер-министром Индии в 2019 году',
#  'как я могу получить привилегию цифрового магазина франшизы',
#  'какие из лучших каналов YouTube для изучения git',
#  'почему не большинство индусов едят не-овощные',
#  'мы можем отменить билет ожидания ожидания таткала',
#  'каковы плюсы и минусы общей инициативы по основным стандартам',
#  'где я могу опубликовать свою статью',
#  'каково ваше творческое разрешение нового года на 2017 год',
#  'как вы не получаете плохих снов?',
#  'делать приседания для мужчин',
#  'какие минимальные отметки я должен забить, чтобы попасть в топ-50 в айым',
#  'врачи: как хирурги проводят на операциях более 6 часов, они отдыхают во время операции',
#  'сколько времени требуется, чтобы научиться разработке приложений для Android с нуля',
#  'как я могу сделать все мое тело более справедливым, если я - пшеничный индийский парень',
#  'если я в тюрьме, какие права у меня есть',
#  'как я могу получить бесплатное сражение камней кланов',
#  'то, что использует объектив word для ocr',
#  'должен ли я беспокоиться о том, что моя подруга пишет своего бывшего бойфренда до 4 м, и если да, то почему',
#  'как получить трафик для сайта',
#  'как он чувствует, чтобы видеть upvotes к вашему ответу на quora',
#  'какие лучшие женские сильные персонажи в фильмах',
#  'как тринадцать лет, что самое лучшее, что я могу сделать для своего здоровья',
#  'как люди умирают',
#  'как производится хлопковая одежда',
#  'Что такое костный мозг?',
#  'в древних римских рабах заклеймили то, что произошло с маркой, если они впоследствии были освобождены',
#  'когда мертвое тело находится в реке, сколько времени требуется, чтобы оно плавало',
#  'как мне пережить кого-то, кого я любил сейчас, когда мы расстались в прошлом году, и я все еще скучаю по ней',
#  'каковы способы изучения мира, не тратя больше денег',
#  'как я могу зарабатывать деньги в Интернете',
#  'где я могу найти вкусные кексы на золотом побережье',
#  'насколько успешным был делийский нечетный - даже план',
#  'кто победит, если начнется война между Индией и Пакистаном',
#  'как вы можете уменьшить свой страх смерти?',
#  'Какова цена, которую я должен заплатить за ремонт сломанного экрана iphone 6, как это можно сделать',
#  'какие самые интересные продукты и инновации выходят в 2016 году',
#  'бесконечность Вселенной или есть конец Вселенной',
#  'Что такое bestmytest com',
#  'сколько денег я должен поднять',
#  'что вы думаете о мр арвинде кейривале и его апа',
#  'каков будет эффект запрета нот 1000rs и 500rs на фондовом рынке',
#  'как сравнить и контрастировать концентрические и эксцентрические сокращения',
#  'почему люди не задают вопросы о новостях и мнениях, размещенных на сайтах социальных сетей',
#  'какие онлайн-платформы я могу публиковать объявления о возможностях пива',
#  'в чем смысл жизни',
#  'как я должен начинать малый бизнес в строительстве',
#  'какими срочными вкладами являются временные депозиты rd и fd',
#  'зачем нам нужны друзья?',
#  'мы существуем',
#  'каков лучший фильм о триллере в голливуде',
#  'Я изучаю колледж asutosh в kolkata, могу ли я учиться в любом другом колледже в Индии на моем 2-м году',
#  'что происходит, когда вы заполняете бензиновый автомобиль дизельным топливом, каково решение, если такой инцидент произошел',
#  'какие рабочие места доступны со степенью бакалавра в области национальной безопасности',
#  'какие хорошие книги для самостоятельного изучения исчисления',
#  'как и почему вы расстались с вашим бывшим',
#  'поддерживает iphone 5s jio volte',
#  'каковы некоторые неписанные правила для вашего дома',
#  'что является лучшим оправданием для объяснения пробела в один или два года в вашей карьере работы для собеседования',
#  'каковы некоторые песни для сладкого воздушного голоса меццо',
#  'что вы можете рассказать мне относительно этой диаграммы рождения?',
#  'которые были создателями тригонометрии',
#  'люди говорят, не пытайтесь угодить другим, потому что это приятно другим людям, которые им нравятся',
#  'как страны должны предотвращать войну',
#  'как я могу стать миллиардером в финансах',
#  'как я могу узнать о веб-дизайне',
#  'есть веб-служба, которая может отправлять напоминания о встречах для клиентов, извлекающих данные из Google Calendar',
#  'каковы будут последствия запрета валютных нот 500 и 1000 рупий на индийскую экономику',
#  'что делает понимание смерти философским',
#  'собаки плотоядные животные',
#  'каково это быть в отношениях с кем-то, кого вы обманывали',
#  'если я отключу свой идентификатор пользователя, я могу написать кому-то, кто заблокировал меня',
#  'какое самое вкусное блюдо вы когда-либо ели и почему',
#  'как быть частным банкиром в Швейцарии',
#  'что такое журналистика',
#  'как я могу улучшить свою концентрацию',
#  'как вы можете персонализировать приглашение linkedin, я думаю, что я просто послал коллеге приглашение на linkedin, но не получил возможность персонализировать его!',
#  'каковы плюсы и минусы наличия домашней птицы-пастуха',
#  'какая разница между хобби и привычкой',
#  'это нормально для мужа и жены, чтобы мастурбировать вместе, это считается обманом, если ваш партнер мастурбирует без вашего согласия',
#  'могу ли я получить работу в консалтинговой фирме после mtech в cse от iit',
#  'что является биологической причиной плача',
#  'как земное ядро \u200b\u200bвлияет на его корку',
#  'если парень пересматривает свои текущие отношения и чувства, если он беспокоится о соблазне, болтающем с девушкой, с которой он дружил',
#  'как я могу подделать свое местоположение iphone без джейлбрейка',
#  'как вы бросили курить?',
#  'который является лучшим языком программирования',
#  'как работают здания, устойчивые к землетрясениям',
#  'Дженнифер Лоуренс - плохая актриса',
#  'почему большинство парней в Индии становятся настолько отчаянными, что они не знают, что девочки не всегда ищут отношения, это повредит парням, чтобы стать нашим другом первым',
#  'что это такое, как на сегодняшний день пума или сахарный папа',
#  'как мне разорвать мой график времени на 4 месяца, чтобы взломать ворота 2016',
#  'которые являются лучшими мобильными телефонами для покупки до 15000',
#  'как я начинаю бизнес из ничего',
#  'кто-нибудь когда-либо имел почти смертельный опыт',
#  'как я могу держать свою собаку от блох',
#  'когда была создана буква j',
#  'курсы Гарвардского колледжа: что такое общий совет по шопингу для уроков тамила',
#  'как я переношу свои контакты с одного телефона Android на другой Android-телефон',
#  'какая самая важная книга, которую вы когда-либо читали',
#  'в каких университетах сигма-альдрих набирает новых сортов из того, что ищет майоры',
#  'Я студент-магистр, желающий работать в гуманитарном секторе, каковы требуемые навыки. Я врач, занимающийся мастерами в Великобритании.',
#  'какие университеты занимаются разработкой диаграмм, набирают новых выпускников из того, что они ищут',
#  'какие лучшие культовые плакаты',
#  'может ли вся биткойнная добыча быть сделана одним малиновым пи',
#  'как ты расист',
#  'в чем разница между',
#  'что канадцы называют Канаду',
#  'как бы вы нашли нуль функции для математики y = frac 4x ^ 2 - 36x x - 9 math',
#  'как добавить второе устройство в аккаунт Google Play',
#  'что я должен делать, чтобы быть хорошим оратором',
#  'как я могу писать в narendra modi',
#  'кто более бредовый: Donald trump или ted cruz',
#  'если снег снега не является ублюдком, почему дама в целом ненавидит его так много',
#  'каковы ваши теории о бермудском треугольнике',
#  'девушки любят черных парней без бороды',
#  'ты бы жил в крошечном доме',
#  'я 18-летний мальчик, и я люблю девушку, которой 14 лет мы оба живем, таммини-наду, это время предложить ей',
#  'сколько и с чем я должен кормить своего 3-месячного ворона',
#  'что я должен делать, чтобы избежать депрессии и тревоги',
#  'это плохое дыхание, признак сильного желудка',
#  'я девушка, и я люблю своего лучшего друга, который тоже девушка, что я должен делать',
#  'которые являются лучшими университетами Германии для получения степени в области машиностроения',
#  'как я могу поддерживать свое спокойствие',
#  'это Volkswagen хороший надежный автомобиль',
#  'каковы причины и наиболее эффективные способы лечения или лечения головных болей мигрени',
#  'каково краткое сравнение kmc в манипуляции и мангалоре',
#  'что я должен делать, когда мой лучший друг игнорирует меня',
#  'какие полезные приложения для телефонов Android недоступны в игровом магазине google',
#  'как вы мотивируете, когда вы изучаете новый язык?',
#  'которые являются ведущими фирмами в области оценки навыков в Индии и во всем мире',
#  'смайлики: что значит: означает',
#  'что сделал Николай Пирамал с 17500 ср',
#  'что было бы лучшим способом удержаться в тюрьме',
#  'где работают ученые',
#  'что такое офисная культура и вокализм в офисе patanjali haridwar',
#  'в чем разница между свадьбой в китайском и западном стиле',
#  'предпочтительные курсы pg для ученика eee в tamil nadu',
#  'какая разница между оффшорными и наземными',
#  'почему люди ненавидят шарух хана и почему люди чувствуют, что он не индийский',
#  'какие книги для самостоятельной помощи мне следует читать',
#  'то, что всегда используется для',
#  'как я начинаю свое продолжение за дар магии',
#  'какие хорошие лирические песни, чтобы отправить своих лучших друзей',
#  'Я девушка в средней школе, мои лучшие друзья - это все девушки, которых я узнал, что я бисексуал, как я могу сказать своему лучшему другу, что девушка без нее волнуется, и это меняет всю нашу дружбу',
#  'краска для волос поможет пройти тест на наркотики для фолликулов для ежедневных курящих мужчин',
#  'как я должен вносить свой вклад в проекты с открытым исходным кодом',
#  'если вы мечтаете о каком-то вреде, будут раны в реальной жизни',
#  'действительно ли крикетцы пьют чай во время перерыва на чай',
#  'каковы требования к выбору в',
#  'как плод выдыхает в утробе матери',
#  'есть ли какой-нибудь хороший фильм об инцесте',
#  'парень, с которым я встречаюсь, никогда не пишет меня, и я чувствую, что он не заботится обо мне, но когда я вижу его, он показывает мне, что он любит меня и хочет меня, почему я так себя чувствую',
#  'какой тип ленты можно использовать для подъема 200 кг непрерывно',
#  'почему оберон наказывает титанию в мечте летнего солнцестояния',
#  'вы когда-нибудь сожалели о своем разводе',
#  'сколько человек может измениться от рождения до смерти в течение примерно 70 лет',
#  'какие интересные факты о Facebook',
#  'есть ли какие-либо сильные признаки того, что козырь Donald кокаина',
#  'какова программа для карты географии icse 2017',
#  'почему программы карьеры могут быть более полезными, чем высшее образование, если вообще начинающим предпринимателям и магнатам',
#  'Каким образом можно смотреть комедийные ночи с капилом на концертах',
#  'который является sandeep maheshwari',
#  'есть ли игра для монстров-охотников',
#  'имеет значение, из какого колледжа вы делаете свой выпускной bcom для поступления в высшую индийскую школу, даже если я нахожу высокий 99 +',
#  'почему не должен я смотреть порно',
#  'как можно научиться доверять снова',
#  'каков ваш список ведер',
#  'как ты впервые в порно',
#  'какие автомобильные услуги доступны в атланте, насколько хороши они по сравнению с такси и относительно друг друга',
#  'почему натриевые каналы не проходят через калиевые каналы',
#  'как я могу избавиться от чувства, что мой супруг обманывает меня?',
#  'который является лучшим общежитием не девочек в srm',
#  'как можно описать драйв из Бруклина на остров Статен и как эти туристические достопримечательности этих городов сравниваются с другими туристическими достопримечательностями',
#  'здорово есть целый авокадо каждый день',
#  'как получить уведомления о значке facebook на htc 10',
#  'что теперь будет делать клинтон',
#  'как вы применяете пузырьки пара, чтобы лечить душный нос',
#  'как я готовлюсь к net jrf в английской литературе',
#  'как они сказали завтрак в португальском, прежде чем кофе был представлен европейцам португальский язык',
#  'который является лучшим графическим дизайнером в Израиле',
#  'как рассказы о канонберах сатиры',
#  'который я должен начать с: угловой 2 или угловой 1',
#  'почему мы засыпаем',
#  'Какая твоя любимая сцена сцене в фильме о чуде?',
#  'каковы ваши взгляды на запрет на 500 и 1000 рупий в Индии?',
#  'как вы находите фигуру, помеченную таким образом в учебнике',
#  'Я фриланс-музыкант, как я могу попасть в jingle-индустрию',
#  'почему соленые таффи конфеты импортированы в Китае',
#  'как я могу присоединиться к',
#  'что самое лучшее, что вы когда-либо узнали о quora',
#  'если Израиль и Иран отправятся на войну, кто победит',
#  'мне почти 40 лет, мне слишком поздно изучать фортепиано',
#  'что наименее натуральное число',
#  'на котором можно купить мото или один плюс 3 т',
#  'я потерял весь свой идентификатор, я принят, и не могу получить доступ к моему оригинальному свидетельству о рождении, как я могу заменить свой идентификатор без свидетельства о рождении',
#  'возможно ли путешествовать быстрее, чем свет',
#  'каково это быть пожарным',
#  'какова основная платформа данных',
#  'нам нужна секция ipc 375',
#  'какое альтернативное слово для творчества',
#  'shaquille o neal считает, что тим-дункан обладает силой вперед, поэтому дисквалификация дункана из nba великой большой дискуссии мужчин не имеет смысла',
#  'почему я чувствую, что я взволнован чем-то, когда мне нечего волноваться',
#  'какие уроки жизни вы можете узнать у темного рыцаря',
#  'как вы прекратите преступную попытку похитить вас и убежать невредимым',
#  'как мне начать продавать на амазонке',
#  'daniel ek: существуют ли какие-либо планы на будущее в области выделения в Индии?',
#  'какие книги стоит читать в начале 20-х годов',
#  'какую книгу я начинаю с подготовки ворот',
#  'то, что вызывает любовь в любви, означает',
#  'что похоже на 4shared, но лучше',
#  'если кто-то схватит вас за вашу рубашку обеими руками и скажет вам заткнуться, это нападение, и вы можете позвонить в полицию',
#  'что это за модельное имя, я вижу ее везде',
#  'какие хорошие рецепты пиццы',
#  'что такое хорошие альпинистские институты для начинающего уровня альпинизма',
#  'как вы разблокируете автомобиль с теннисным мячом',
#  'могу ли я снять свои деньги с какого-либо филиала конкретного банка, мой банк - банк барды, у меня нет карточки атташе и чековой книжки',
#  'что такое обложка',
#  'согласно m-теории существует 11 измерений, почему только 5 измерений в отношении гравитации рассматриваются в межзвездных',
#  'я имею ужасное зрение, могу ли я по-прежнему стать летчиком-истребителем в воздушной силе',
#  'как я делаю пробуждение обратно в постель ясная техника сновидений, когда я думаю, что у меня синдром беспокойства ноги, независимо от того, что у меня болят ноги ночью',
#  'были испытаны мифические существа',
#  'может быть отменено или приостановлено глобальное изменение климата',
#  'что я должен просить о моей подавленности',
#  'существует ли гравитационная сила во всех планетах',
#  'действительно ли произошло махабхарата или только аллегория в соответствии с m k gandhi',
#  'что является хорошим источником для покупки адресов электронной почты адвокатов',
#  'здорово ли потерять 13 фунтов в месяц',
#  'когда конец серии pok mon',
#  'почему полицейские огни красные и синие',
#  'почему мой вопрос был отмечен как улучшение потребностей',
#  'который владеет природными факторами',
#  'Я хочу установить exe файлы расширения в Android-мобиль, это возможно',
#  'что такое стоимость мусора в c',
#  'Каковы наилучшие способы подготовки к интервью с программным обеспечением?',
#  'у rahul gandhi есть шансы стать следующим pm of india после modi',
#  'хорошо делать спортзал утром и плавать в полдень',
#  'в чем разница между астероидами и кометами',
#  'почему нерафинированное молоко хорошо для вас',
#  'какие уловки для эффективного изучения',
#  'которая является лучшей страной для высшего образования после США и Великобритании',
#  'что это за картина?',
#  'которые являются основными автомагистралями в Калифорнии и как они сравниваются с основными магистралями в техасе',
#  'если пространство расширяется, где новое пространство исходит из',
#  'может лысый человек когда-либо вырастить свои волосы назад',
#  'как отличается чили между культурами',
#  'что это значит, когда парень говорит, что он в безопасности',
#  'что отличает хорошего программиста',
#  'мировая война iii неизбежна',
#  'есть ли у нас риск какого-то восстания после выборов',
#  'каковы лучшие страны для осведомителей, ищущих убежище',
#  'каковы кружки на полях',
#  'как пищевая сода поможет вам пройти тест на наркотики',
#  'как распространен вирус зики',
#  'как вы научитесь алгебре 1 быстро',
#  'действительно ли повторное сдача предметов в колледже влияет на будущие перспективы работы',
#  'как я могу получить свое имя с первой страницы в google search',
#  'почему произошла битва agincourt, как она сравнивается с битвой краевого холма',
#  'цветы: что такое вайджанти',
#  'какое лучшее место для секса от',
#  'увеличивает анемию раздражительность',
#  'должен ли я получить новый macbook pro',
#  'выпивка вызывает долговременное повреждение головного мозга',
#  'в чем разница между китайской и западной культурой',
#  'какие хорошие методы очистки скребков для веб-скребок',
#  'где я могу найти лучшие камеры безопасности',
#  'здорово есть одну курицу каждый день',
#  'могут хинди слова получить место в оксфордском словаре',
#  'почему я не чувствую угрызений совести',
#  'сколько минут йоги можно сделать за один день',
#  'почему моя собака укусила меня',
#  'как я могу получить серьезное растяжение',
#  'какие симптомы серьезного крика на шее',
#  'Каковы лучшие места для посещения в непале',
#  'Я устал от ноутбуков, которые купили старые и медленные, после того, как в течение двух лет рабочие столы деградируют, так как быстро получит твердотельный накопитель для ноутбука, который поможет увеличить его долговечность',
#  'какой компании я должен выбрать hsbc glt или cybage software',
#  'как плохо провалил Дональд Трамп, его побег будет иметь значение бренда',
#  'сколько баллов я должен забить в ssc cpo, чтобы получить дели полиции',
#  'мы движемся к мировой войне 3',
#  'как написать песню',
#  'что следующий шаг после демонизации',
#  'если у вас есть я, вы хотите поделиться мной, если вы поделитесь мной, вы не получите меня, что я',
#  'что самое интересное, что большинство людей не знают о',
#  'почему мы не разработали реактор слияния, способный генерировать больше энергии, чем он потребляет то, с чем мы сталкиваемся',
#  'есть рабочий эмулятор nintendo 3ds для ПК',
#  'где я могу купить дешевую одежду оптом',
#  'как я могу стать хорошим инженером в области компьютерных наук',
#  'как работает clockworkmod для телефонов, не имеющих разблокировки загрузчика',
#  'это правильный вариант от того, чтобы быть разработчиком Android, чтобы стать переводчиком через 3 года в области разработки программного обеспечения',
#  'как я могу преуспеть в программировании, не тратя впустую четыре года в степень cs в индийском инженерном колледже',
#  'как ваш опыт ясного сновидения',
#  'каково это быть привлекательным и желательным для многих',
#  'что должно быть сделано дальше, чтобы подать заявку на участие в гранте в государственном учреждении, если я очистил тестовый тест tifr gs 2016',
#  'как я могу взломать другую учетную запись whatsapp',
#  'sms usc купить ucla',
#  'какой самый важный урок вы извлекли из жизни',
#  'какие лучшие мобильные приложения для рекрутеров',
#  'как бы козырь президентства повлиял на индийских студентов в нас',
#  'каков порядок бэтмен: аркхам игры',
#  'какие хаки в повседневной жизни',
#  'сколько веса я теряю при чистке после каждого раза, когда я ем',
#  'какой ваш любимый персонаж аниме и почему',
#  'как работает транзакция atm',
#  'сколько инженеров-механиков ежегодно заканчивают в Индии',
#  'что вам нужно для создания собственной частной акционерной компании',
#  'что является наиболее недооцененной деятельностью',
#  'что должны знать все студенты машиностроения',
#  'Каковы лучшие места для посещения в Керале для студентов колледжа',
#  'почему так много вопросов о iq-вопросах о quora',
#  'как я могу уничтожить мир',
#  'как я зарабатываю деньги через youtube',
#  'как я могу полностью отключить подсветку синтаксиса в возвышенном тексте для golang',
#  'могу ли я увидеть упорядоченный список людей, с которыми я обмениваюсь самыми общими друзьями на facebook',
#  'когда он стал публичным человеком, и каков был его подъем к известности, как',
#  'как я начинаю писать',
#  'как произошел большой взрыв, когда не было времени для его возникновения в',
#  'почему я хочу остаться одиноким всю свою жизнь после моего распада, почему я чувствую, что я закончил эту серьезную связь',
#  'когда я должен начать подготовку к экзамену гражданской службы',
#  'каковы неинвазивные системы мониторинга уровня глюкозы в крови в Индии',
#  'какая разница между сексом и мастурбацией, когда дело доходит до удовольствия',
#  'почему некоторые люди верят, что жизнь заканчивается смертью',
#  'как начать бизнес солнечной энергии?',
#  'имеет ли веб-методы будущее через 5-10 лет',
#  'у вас есть психическая сила',
#  'как вы управляете временем между работой и учебой',
#  'можно ли дать шаг 1 после 8 лет пробела',
#  'это urjit patel - правильный человек для губернатора rbi',
#  'вы хотели бы стать президентом',
#  'как отношения Индии с американским',
#  'как отреагируют сторонники козыря, как только они поймут, что он не может или не будет выполнять свои обещания в кампании',
#  'как я могу эффективно учиться во время сна',
#  'вы можете играть в азартные игры 4 на европейской игровой станции 4',
#  'Как я могу перестать смотреть порно',
#  'почему uk имели плохие жизненные стандарты в 70-х годах 80-х годов, но теперь лучше',
#  'как может студенческая помощь в исследовании машинного обучения',
#  'с 2015 года, каково будущее развития ios',
#  'что вы чувствуете, является целью жизни',
#  'как девушка получает парня',
#  'вы думаете, что путешествие во времени возможно',
#  'как мне сделать, чтобы получить более полное лицо',
#  'Я хочу начать свою карьеру фотографа в возрасте 25 лет, слишком поздно',
#  'когда самое лучшее время для секса',
#  'почему сталь и алюминий не могут быть сварены вместе',
#  'как это возможно для видео с YouTube, которому больше не нравятся не нравы, чем мнения',
#  'возможно ли, чтобы правительство Шарифа разрешило конфликты в Кашмире',
#  'если я вырыл огромную дыру в земле по прямой, что произойдет, когда я доберусь до противоположной стороны земли, сначала моя голова или мои ноги',
#  'как мы производим свободную энергию',
#  'Что такое веб-дизайн?',
#  'какие самые смешные анекдоты вы когда-либо слышали',
#  'что такое коэффициент фенотипа',
#  'почему время, кажется, проходит так медленно, когда вы находитесь в скучной лекции',
#  'у знаменитостей Болливуда есть свой собственный реактивный самолет',
#  'в чем разница между наличием бозе-наушников в ухе и вокруг уха',
#  'какие фильмы вы бы рекомендовали всем смотреть',
#  '3-я мировая война неизбежна, чем ожидалось',
#  'питается черносливом с запором',
#  'вам когда-либо говорили какие-либо снисходительные заявления ваших старших, чтобы доказать свою точку зрения',
#  'мир был бы менее технологически продвинут, если бы две мировые войны никогда не происходили',
#  'какова минимальная сумма инвестиций, если я хочу покупать роялти за нефть и газ',
#  'являются кворансами, поддерживающими modi',
#  'что является хорошим источником для изучения математики',
#  'какие примеры того, как описать человека в положительном свете',
#  'что происходит, когда вы летите в страну, но они отказываются от входа',
#  'почему барак Обама так важен для мира',
#  'Пакистан стал убежищем для глобального терроризма',
#  'как я могу остановить выпадение волос',
#  'какая лучшая классическая музыка из всех времен',
#  'каковы некоторые необычные аспекты политики и правительства в Сингапуре',
#  'Какова цель науки?',
#  'это нормально уволить кого-то по электронной почте',
#  'какие хорошие бюджетные места для проживания в гоа',
#  'есть ли какой-либо веб-сайт, например, quora',
#  'как условия в лагерях для беженцев в Европе',
#  'что является противоположностью взлета',
#  'что вы любите больше всего о своем женихе',
#  'может кто-нибудь объяснить мне, как сделать с шагами эту маленькую проблему',
#  'как я могу увеличить свое присутствие ума',
#  'как бы математика изменила бы 2 плюс 2 была равна 5',
#  'влияет ли мой показатель на кибиль, если я плачу только минимальную сумму',
#  'каково правильное каноническое написание среднеземных работ в tolkien',
#  'что малайцы думают об индейцах',
#  'могу ли я взять 10-месячного ребенка в базовый лагерь har ki dun trek',
#  'как мы можем научиться программированию c',
#  'каковы ваши взгляды на решение верховного суда о том, чтобы играть в национальный гимн обязательно в кинозалах',
#  'если бы одна женщина была избрана президентом Соединенных Штатов, у нее была бы первая леди или первый джентльмен',
#  'как я могу получить электронное обучение moocs через онлайн-курсы и видеокурсы, связанные с фотографией, разработанными индийскими профессорами',
#  'мобильность мобильного номера, наконец, начнется 3 мая, включая изменения кругов, которые сетевые провайдеры действительно согласились с этим',
#  'почему люди так ненавидят сумерки',
#  'вступая в корпоративную жизнь от учебы, как это чувствуется',
#  'lua и c, который является лучшим языком программирования для встроенных систем',
#  'как я могу улучшить английский',
#  'как я могу быть геем и не люблю гей-секс',
#  'я нахожусь в десятом классе в средней школе в онтарио-канаде, я бы очень хотел обменяться со студентом из Европы любыми идеями о том, как я могу это сделать',
#  'как я зарабатываю деньги через youtube',
#  'как мне найти любовь к моей жизни',
#  'можно сжечь 1000 калорий каждый день, если да, как',
#  'как я могу избавиться от человеческих сиськов',
#  'которые являются свободными от стресса, относительно легко получить рабочие места в Индии, которые платят приличную сумму денег и позволяют вам заниматься другими интересами',
#  'какова научная причина посещения храмов',
#  'разрешено обрезание в исламе',
#  'где я могу получить услуги профессиональных фотостудий в Сидней',
#  'как вы отправляете запрос друга на instagram',
#  'как кто-то может контролировать свой гнев',
#  'что такое профилирование пола',
#  'как выйти из кворы',
#  'как долго длится onigiri, если оставить его в холодильнике, как его можно сохранить дольше',
#  'Каковы некоторые из лучших гаджетов для смартфонов',
#  'как чувствует себя гомосексуалистом в Индии?',
#  'насколько важна роль tpm на амазонке',
#  'что произойдет, если диктатура сохранится и в наши дни',
#  'что делает идеальную чашку кофе',
#  'был нами выборный фальсификатор',
#  'gayle laakmann mcdowell планирует опубликовать больше книг, если так, то, над чем она работает',
#  'что такое ферментированные продукты',
#  'что вы думаете о моем короткометражном фильме?',
#  'почему существует конфликт между Индией и Пакистаном на Кашмире',
#  'как я могу получить продовольственные талоны в колледже',
#  'какие примеры рекурсии в реальном мире',
#  'как найти лучшие приложения для защиты Android',
#  'как трудно было бы научиться играть на аккордеоне, если я знаю, как играть на пианино',
#  'какова роль индийской армии',
#  'что такое использование demonetizing rs 500 rs 1000 примечаний',
#  'какие интересные факты о бенгалуру',
#  'если оба родителя имеют группу крови b +, я могу быть +',
#  'которая является лучшей книгой для химии для neet',
#  'что такое просветление',
#  'почему многие пользователи quora задают вопросы, которые они могут найти в Интернете',
#  'какой должен быть ответ, если ваш собеседник попросит вас продать его перо перед собой',
#  '68 44 продукта проходит спецификацию процесса для прохождения продукта, должно быть близко к среднему, сколько стандартных отклонений составляет 68 44',
#  'почему бы нам не отправиться на восток, чтобы отправиться из Индии в США',
#  'мои семейные билеты изменились с раса до подтвержденного cnf, у всех нас будут соседние места после подготовки чартов',
#  'что такое способ создания красивого пользовательского интерфейса',
#  'как улучшить свои навыки обучения',
#  'каковы применения малины pi и intel galileo',
#  'каков ваш лучший фильм 2016 года',
#  'почему центральное правительство запретило старые 500 и 1000 р. примечание, но выпустило новые примечания 500 и 2000 р.',
#  'какая хорошая фотография',
#  'почему люди убегают из дома',
#  'какие модификаторы доступа в java',
#  'Может ли поэзия быть изученной или есть у вас это или нет?',
#  'что такое истина о жизни после смерти, так как есть некоторые неподтвержденные примеры',
#  'мне нужно получить столбнячный снимок',
#  'если гравитационный изгиб свет может ослабить силу тяжести',
#  'какие-то милые способы разрезать юбку',
#  'имеет лотос фактически продал любые автомобили в нас за последние 10 лет',
#  'как отправить другому человеку сообщение о quora',
#  'как я тренирую белые питбуллы',
#  'почему индейка имеет более темное более аккуратное темное мясо, чем куриное',
#  'что самый сюрреалистический вопрос о quora',
#  'каковы различия между информатикой и компьютерной инженерией',
#  'какое лучшее время для секса',
#  'есть ли хорошие бесплатные онлайн-астрологи',
#  'почему я не хочу разговаривать с кем-то',
#  'почему мы ненавидим наших сестер',
#  'что хороший торрент-сайт для загрузки игр из',
#  'что вызывает смерть, вися',
#  'как wifi латентность по сравнению с проводной ethernet',
#  'я изучаю компьютерную науку bs, я нахожусь в 7-м семестре и не могу пройти базовый курс программирования, потраченный впустую много денег',
#  'какие поведенческие адаптации делают красные панды',
#  'хорошо текстильная техника или нет',
#  'какой самый быстрый уличный юридический автомобиль в мире',
#  'что представляют собой магниты из',
#  'что истинное значение',
#  'что нужно, чтобы стать агентом fbi',
#  'какая лучшая операционная система для ПК',
#  'сколько телеканалов есть в мире',
#  'каковы некоторые изобретения эпохи неолита',
#  'почему кворы отмечают мои вопросы, так как нуждаются в уточнении улучшения, прежде чем у меня есть время, чтобы дать ему детали буквально в течение нескольких секунд',
#  'как я могу нанять хакера',
#  'какие из лучших ужасных романов 2014 года',
#  'какая самая красивая вещь когда-либо построенная',
#  'почему я должен жить',
#  'каков точный смысл жизни',
#  'что я могу сделать, когда мой друг предал меня',
#  'я 22 мой вес 46 кг, а мой рост 5 футов, что я должен сделать, чтобы получить высоту и вес',
#  'почему соленые таффи конфеты импортированы в лаос',
#  'почему мексиканский город опасен',
#  'сколько стоит заказать хорошее свадебное место',
#  'каковы некоторые из самых удивительных концепций, данных теоретическими физиками, которые не могут быть доказаны в реальности или слишком продвинуты, чтобы доказать наличие доступных ресурсов технологий',
#  'что важнее денег или уважения',
#  'кто лучший индийский хакер',
#  'нам нужно изменить систему образования Индии, если да, то почему',
#  'каков стандартный размер столбца для построения',
#  'каковы некоторые из наиболее часто ошибочных английских слов',
#  'девочки получают подавление от своих учителей-мужчин',
#  'слишком поздно ходить в медицинскую школу по 24',
#  'где я могу получить качественные услуги для очистки краски и удаления краски в чатвуд',
#  'если я скриншот кому-то видео в реальном времени на instagram, они получают уведомление',
# ...
#  'как я должен перестать думать о ком-то',
#  'Что такое взаимный фонд?',
#  'при вычислении вращения пули; mv x 12 коэффициент кручения в дюймах x 60 = об / мин делает расстояние до целевого вещества',
#  'как вы собираетесь поддерживать акустическую бас-гитару',
#  'какие университеты в нас предлагают более технический контент в учебной программе управленческих информационных систем',
#  'я хочу сделать bba, я получил только 62 в классе 12 non maths, я беру 1-летний кадр для вступительного экзамена на симбиоз ggsipu и т. д., должен ли я также улучшить ситуацию в следующем году',
#  'что такое функциональное программирование',
#  'в чем разница между марксизмом социализма и коммунизмом',
#  'как я могу войти в facebook без пароля',
#  'как слово, искаженное, используется в предложении',
#  '3d rad: как я могу сделать миссию',
#  'как компании зарабатывают деньги',
#  'какие самые завышенные фильмы',
#  'в глубоком изучении того, как мы обновляем вес в нейронной сети',
#  'который я должен сначала изучить: c + + или c',
#  'что является самым точным носимым предметом для деятельности на рынке сегодня i e jawbone или fitbit',
#  'что является свидетельством существования и против существования исторического иуда',
#  'предложите мне бесплатные онлайн-курсы, предоставляющие сертификаты',
#  'я работал в течение 1 месяца и скрывался от акцепта в течение периода облигации, они будут принимать любые судебные иски, это повлияет на присоединение к другой компании',
#  'какие из лучших оплачиваемых рабочих мест, которые можно сделать из дома',
#  'есть большой шанс, что козырь победит на выборах',
#  'какие курсы по информатике я должен принять, если я хочу присоединиться к продуктовой или электронной коммерции',
#  'как я могу встретить suresh raina',
#  'как называется песня, в которой салман-хан дразнит мадхури-диксит, используя рогатку и из какого фильма',
#  'какова функция центросом в растительных клетках',
#  'каковы некоторые примеры доказательств эволюции, которые содержат ископаемые записи',
#  'каково движение g len',
#  'необходимо изучать ведические математики и проводить время на коротких трюках для экзамена на кошку 2016 года',
#  'что делают мифические существа',
#  'у нас был консенсуальный секс, тогда он заставлял меня заниматься анальным сексом, если я настаиваю на обвинениях в том, что я согласился на секс вагинально, разрушив мой случай',
#  'какая погода похожа на зиму в Тель-Авиве',
#  'каковы лучшие акции для инвестиций в долгосрочной перспективе',
#  'как улучшить навыки чтения',
#  'то, что я должен делать, если кто-то разместил порно видео под своим именем',
#  'будет есть 2 000 калорий в день, чтобы я похудел',
#  'каковы меры предосторожности при обращении с дробовиками, предлагаемыми nra в Аризоне',
#  'болливудская индустрия не поощряет аутсайдеров для экс-аутсайдеров, может получить одну или максимум два шанса, в то время как у звездных детей есть много шансов на выполнение',
#  'каковы плюсы и минусы приведения небольшого требования в суд перед судом по телевидению',
#  'как я могу попросить моего бывшего вернуться',
#  'какую кросс-платформу я должен выбирать при разработке мобильного приложения для предприятия',
#  'какой лучший способ подготовиться к ялтам',
#  'как я знаю, действительно ли моя подруга по-настоящему любит меня',
#  'если бы нужно было учиться на python, чтобы иметь возможность применить его к своей области обучения, которая была бы важной в математике по математике, какие приложения python могли бы быть наиболее полезными при подаче заявления на работу',
#  'в чем разница между словами кражи со взломом и грабежом?',
#  'теория графов - хороший курс для машинного обучения',
#  'которые являются лучшими школами для изучения обработки естественного языка',
#  'поддержит Дональд козырь ted cruz для президента',
#  'каково значение gdp',
#  'кто будет новым американским президентом, почему',
#  'что вам нужно сделать, чтобы стать пилотом авиакомпании?',
#  'как я всегда лечу анальную трещину с помощью домашних средств',
#  'как я могу получить лучший результат в gre',
#  'почему душа бессмертна',
#  'каковы некоторые из ваших личных персонажей в истории и событиях 1-го дома',
#  'Каков наилучший способ уменьшить загрязнение в Индии?',
#  'ubermoto юридический в Индии',
#  'что я думаю, что вы имеете в виду',
#  'который является лучшим местом для празднования нового 2015 года в Гидерабаде',
#  'что усердно работает с точки зрения изучения',
#  'У меня Windows 7 32 бит я могу обновить до 64-битных окон 10, так как это бесплатное обновление',
#  'какие были твои хорошие и плохие жизненные переживания',
#  'какой бренд барабанов делает timbaland использование',
#  'как вы получаете номера сотовых телефонов',
#  'вам нужно просыпаться посреди спального сна, чтобы помнить мечты',
#  'то, что обычно требуется, и выборные курсы по философии',
#  'я хочу учиться пению, как я начинаю',
#  'виртуальная монополия google в веб-поиске когда-либо заканчивается, когда',
#  'что вызывает аутоиммунные заболевания',
#  'делает gta iv работы над окнами 10',
#  'который институт обеспечивает лучший ssc и банковский коучинг в chandigarh',
#  'который является лучшим центром сертификации pmp в бангалоре',
#  'какова разница между валовым доходом и чистым доходом',
#  'как я могу встать рано утром',
#  'что вам нравится, почему',
#  'когда я должен ожидать, что моя дата присоединения к акквенту будет показана на временной шкале 24 декабря 2016 года, и я не получил никаких обновлений от организации',
#  'в чем разница между iphone 6 и iphone 6s',
#  'какая армия выиграет, если между нами произойдут бои от ww2 и нас войска от войны вьетнамской',
#  'моя сестра сказала мне, что я люблю ее без меня, прося ее сделать это, что я должен делать сейчас',
#  'кто выиграет доваккин из скайрима или кило ren',
#  'что не мусульмане ожидают от мусульман',
#  'что я могу прокомментировать мои фотографии подружек',
#  'во время дождя, что я должен делать для предосторожностей наводнения',
#  'что является самым простым способом доказать принцип неопределенности Гейзенберга',
#  'что такое ielts и его использование',
#  'как я могу потерять вес, не выполняя упражнения или диету',
#  'какие цифровые камеры имеют электронный затвор, который может быть настроен так, чтобы не создавать абсолютно никакого шума или шума',
#  'мне 51, я могу встретить мужчину в его 30',
#  'каковы были причины мировой войны 1',
#  'как я преодолею свои страхи',
#  'какой город в Аргентине имеет лучшую погоду',
#  'каковы различия между ssd и hdd',
#  'почему мой щенок рвет белой пеной',
#  'действительно ли у нас есть какие-то цели в жизни или мы создаем цель, чтобы заставить себя почувствовать себя значительными в самом обширном мире или заставить себя почувствовать, что наше существование в огромном мире требуется',
#  'как ситуация на работе в новой Зеландии для дипломированных выпускников компьютерных наук',
#  'как создать сайт электронной коммерции',
#  'делает iphone 4 использовать микро-сим-карту',
#  'все мои вопросы о quora нуждаются в улучшении, что является лучшим способом задать вопрос о quora',
#  'в эпоху, когда мы постоянно видим, как лучшие люди работают и живут, как мы не чувствуем себя неудовлетворенными нашей собственной работой и жизнью',
#  'как я могу научить себя тому, как петь',
#  'какие грубые комментарии человек получит в Соединенных Штатах, если он датирует женщину на 30 лет моложе его',
#  'если французы фермеры, актриса все еще была вокруг сегодня, что бы она подумала о конусе Дональда',
#  'какие хорошие заменители сыра для сыра гаварти',
#  'может запор вызвать головокружение',
#  'что является гарантийным сроком для микро-наушников-вкладышей?',
#  'что за плюсы и минусы клинтона холма',
#  'я хочу взволновать, какой фильм я должен смотреть',
#  'как я могу гарантировать, что сперма не выходит из моего пениса после того, как я эякулят',
#  'которые являются лучшими ssc и банковскими коучинговыми центрами в chandigarh',
#  'что будет следующим номером в серии - 2 15 4 12 6 7',
#  'что нам нужно, чтобы иметь лучший Хэллоуин',
#  'мне 17, и я хочу вкладывать деньги на фондовый рынок, где я должен начать',
#  'почему компания выпускает бонусные акции',
#  'вы думаете, что уничтожение 500 и 1000 рупийских деноминаций приведет к искоренению коррупции',
#  'что я должен делать в групповом обсуждении, когда другие продолжают сражаться и не позволят мне поговорить даже после того, как я попрошу их отпустить меня',
#  'который является лучшим производителем специализированного киоска в Индии',
#  'есть ли у нас телескопы, достаточно мощные в наши дни, чтобы увидеть созданные человеком объекты на Луне с помощью миссий apollo, доказывающих 100, что люди действительно на самом деле пришли туда',
#  'есть ли онлайн-программное обеспечение для расчета временной и пространственной сложности java-программы в больших o',
#  'сколько ключевых слов есть в языке программирования сценариев autoit в последней версии',
#  'что самое сложное в воспитании детей в Мексике',
#  'что является лучшим презентационным программным обеспечением для вас, как платным, так и бесплатным',
#  'почему Индия всегда саботирует и разрушает все экономические проекты Пакистана с другими странами мира',
#  'почему чувствуешь, что в моем влагалище есть мяч?',
#  'почему популярная серия телевидения с большой ошибкой настолько популярна, почему она так популярна среди обычных зрителей',
#  'как вы можете увеличить свой рост',
#  'вас когда-либо уволяли, как вы с ним справлялись',
#  'как бы я одевался как гуру тренировки с 1990 года летом',
#  'моя подруга не разговаривает со мной, что мне делать',
#  'как отменит рупий 500 и 1000 руб., повлияет на недвижимость в Индии',
#  'какие вопросы лучше всего задавать',
#  'вы считаете, что доверять другим людям достаточно мудро, после того как его предают кто-то еще',
#  'которые являются лучшими охотниками за головами',
#  'может использоваться вакцина против бешенства для людей',
#  'какая разница между канатной дорогой и канатной дорогой',
#  'были проведены медицинские испытания',
#  'почему так важно морское право',
#  'как долго я получу обновления os на moto g3',
#  'вам платят, когда вы сражаетесь с компаньонами на jre или это просто для удовольствия',
#  'который был лучшим злодеем в нолан-бэтменских фильмах',
#  'почему так много наготы в игре тронов серии tv',
#  'как я могу получить больше последователей в своем блоге',
#  'я хочу взломать ca cpt через 2 месяца, как я должен учиться',
#  'какой язык программирования я должен узнать, хочу ли я разрабатывать игровые приложения',
#  'каковы ваши взгляды на демонизацию 500 1000 заметок в Индии',
#  'почему сыновья тата заменили цирус-мистрию на ratan tata',
#  'плата за автострахование в Калифорнии',
#  'почему я так зол',
#  'почему люди, которые сделали магистерские степени в любой области, советуют вам не делать мастер',
#  'каковы некоторые последствия отключения электроэнергии',
#  'каков риск продажи биткойна и принятия платежа по кредитной карте',
#  'почему у многих людей в нас есть яблочный телефон или ноутбук',
#  'что самое первое, что вы помните в своей жизни',
#  'что мы можем сделать после завершения бдс',
#  'почему мусульмане ненавидят modi правительство',
#  'что я могу сделать, когда мне 18 лет',
#  'какие лучшие романтические фильмы комедии',
#  'младенец-лев, воспитанный в возрасте до четырех лет, может выжить, если его выпустят в дикой природе',
#  'поиск практического применения 6 бит adc',
#  'как мне начать медитировать и когда',
#  '- потенциальная энергия виртуальных частиц энергии вакуума и или темная энергия бесконечная без слияния',
#  'является bihar, развивающимся под руководством главного министра nitish kumar',
#  'каковы побочные эффекты гомеопатических лекарств',
#  'который является лучшим музыкальным проигрывателем до 5000 inr',
#  'каковы будущие возможности для операций логистики закупок и управления цепочками поставок',
#  'как я могу присоединиться к wikileaks',
#  'если вы публикуете фотографии в социальных сетях',
#  'мы можем контролировать наши мечты, можем ли мы мечтать о том, о чем мы хотим мечтать',
#  'как успешные отношения на большие расстояния',
#  'Мне 26 лет, я просто ударил 4 миллиона долларов, я стреляю по 40 на 35 утра, я ошибаюсь, думая, что жить в самой дорогой области страны даст мне лучшие возможности',
#  'британцам будет разрешено переехать в Евро и жить там после того,',
#  'у конуса Дональда есть шанс выиграть предстоящие выборы',
#  'лучшие обои для iphone',
#  'как восстановить фотографии в хранилище приложений в мобильном телефоне Android',
#  'онлайн-центры тестовых центров',
#  'почему кастовая система существует в Индии даже после 7 десятилетий независимости',
#  'как я могу получить парня в возрасте 13 лет',
#  'какой будет мой ранг в neet 2016, если мои отметки - 391',
#  'seo или smo, которые помогают получить больше бизнеса',
#  'что такое политика избыточного финансирования',
#  'какие методы маркетинга для языковых школ',
#  'сколько зарабатывает олимпийский золотой медалист в Китае',
#  'как я могу зарабатывать деньги в Интернете?',
#  'в чем причина реактивности конденсатора',
#  'amazon com снижает стоимость жизни в высокоразвитых областях, таких как кремниевая долина',
#  'какие лучшие школы в мире изучают кино?',
#  'почему в качестве консервированной конфеты в Австрии',
#  'почему нулевой факторный 0! равный 1',
#  'какие лучшие рабочие места, которые мы можем делать в бангалоре',
#  'как вы становитесь довольно привлекательным',
#  'что считается лучшим музыкальным альбомом',
#  'почему Дональдский козырь так поддерживает, что произойдет, если он выиграет выборы',
#  'каковы симптомы аутизма у девочек',
#  'каково это быть некурящей матерью курящих детей',
#  'жизнь - мечта или реальность',
#  'могу ли я комфортно жить в DC на 80 000 - 114 000 зарплат',
#  'как узнать, есть ли у девушки бойфренд',
#  'каковы преимущества употребления авокадо',
#  'как я могу создать рабочую модель по математике',
#  'как я могу получить здоровый вес и массу',
#  'какое животное ты',
#  'то, что купили больше онлайн',
#  'можно ли по-прежнему иметь приличный кредитный рейтинг после главы 7',
#  'как я могу знать, что он мой родственник',
#  'как я должен быть человеком',
#  'делать отношения междугородных отношений',
#  'как я могу понять английский',
#  'какова была ваша самая большая проблема в качестве государственного секретаря',
#  'что такое рамки в неспециалистских терминах',
#  'делает okha экспресс обеспечивает пищу',
#  'где я могу найти хорошего хакера',
#  'как изменить зарегистрированный номер мобильного телефона для банковского счета dbs',
#  'каковы некоторые советы о том, чтобы сделать это через процесс собеседования на собеседовании в t',
#  'каковы основные объемы импорта и экспорта венесуэльской продукции и как отрасль венесуэлы сравнивается с боливией',
#  'как роли cia nsc и других связанных организаций отличаются друг от друга и связаны друг с другом сейчас и в прошлом',
#  'каковы лучшие фильмы для просмотра',
#  'вы можете скачать cydia на своем устройстве без джейлбрейка',
#  'как я могу получить работу в Google или Microsoft',
#  'fahrenheit 451 1953 книга: что такое парень montag тезка',
#  'Каков ваш обзор любви на скалах 2004 года?',
#  'возможно ли проехать назад или вперед во времени?',
#  'почему мы получаем морской бриз летом, но редко зимой',
#  'как восстановить удаленные сообщения facebook',
#  'обслуживание клиентов: что такое uber номер телефона',
#  'есть ли способ купить телефон на emi через флипкарт с только дебетовой картой, как',
#  'что такое гибкая и сложная модель',
#  'моя жизнь скучна, что я могу сделать',
#  'где я могу купить мельдоний в американском',
#  'что может быть самым сумасшедшим способом совершить самоубийство',
#  'составляет 100 76 ок кровяное давление',
#  'каковы ваши лучшие паранормальные переживания',
#  'что именно вьяпамский жулик, почему так много умерло из-за этого',
#  'мой жених умер недавно, и мне больно, как я научусь справляться с этим',
#  'в Сидней, какая компания будет лучше всего получить консультацию по покупке бизнеса',
#  'почему в большинстве косметических продуктов нет ценников',
#  'мы можем сопоставить поверхность и подповерхность планеты с помощью космических лучей или очень высокочастотных гамма-лучей с наземными телескопами',
#  'дайвинг синей дыры в дахабе',
#  'как преобразовать необработанные файлы в jpeg',
#  ...]

# %%
### реализуйте эту функцию ранжирования 
from math import log

k = 2.0
b = 0.75
lengths = [len(doc) for doc in corpus]
avgdl = sum(lengths)/len(lengths)
N = len(corpus)

def q_score(q, N, doc, len_doc):        #подсчёт score отдельного слова
    n = np.count_nonzero(result1[q])
    tf = len(re.findall(' '+q+' ', doc))
    idf = IDF(N, n)
    score = idf*((tf*(k+1))/(tf+k*(1-b+b*len_doc/avgdl)))
    return score
    
def bm25(query, doc) -> float:   #query подать уже нормализованную))
    doc_contents = doc.split(' ')
    len_doc = len(doc_contents)
    scores = []
    for q in query:
        try:
            scores.append(q_score(q, N, doc, len_doc))
        except KeyError:
            scores.append(0)
    return sum(scores)

def IDF(N, n):   # qi - одно слово из запроса
    idf = log((N-n+0.5)/(n+0.5))
    return idf

# %%
def preprocess_query(raw_query):
    normalized = [pmm.normal_forms(x)[0] for x in raw_query.split() if x not in russian_stopwords]
    return normalized

for_queries = [row[0] for row in data[:1000]]
raw_query = random.choice(for_queries)
QUERY = preprocess_query(raw_query)
print(QUERY)
# Out:
# ['волшебство', 'волшебник', 'научно', 'проверить']

# %%
def preprocess_query(raw_query):
    normalized = [pmm.normal_forms(x)[0] for x in raw_query.split() if x not in russian_stopwords]
    return normalized

# %%
with open('lemmatized.txt', 'r', encoding='utf-8') as f:
    content = f.read()
    lems = content.split('\t')

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(lems[:10000])
result1 = pd.DataFrame(data=X.toarray(), columns=vectorizer.get_feature_names())

# %%
# %%time
bm25_scores = [bm25(QUERY, doc) for doc in corpus]
# Out:
# Wall time: 7min 43s

# %%
output = sorted([(e,i) for i,e in enumerate(bm25_scores)], reverse = True)

# %%
for i in output[:5]:
    print(data[i[1]])
# Out:
# ['Каковы наилучшие способы проверки идеи запуска?', 'как я могу проверить и проверить мою идею запуска', '1']
# ['как вы проверяете статус pf онлайн?', 'Я не могу проверить свой баланс онлайн-счета в сети, как я могу проверить свой баланс в автономном режиме', '1']
# ['какова процедура проверки баланса pf', 'Я не могу проверить свой баланс онлайн-счета в сети, как я могу проверить свой баланс в автономном режиме', '1']
# ['может карма как концепция быть научно доказанной', 'карма научно доказана', '1']
# ['если у меня будет стыковочный рейс, они переведут мой зарегистрированный багаж с одного самолета на другой или мне придется его повторно проверить', 'мой полет от бенгалуру до чандигарха через дели бит, я хочу проверить в Дели, можно проверить в Дели с моим багажом', '0']

# %% [markdown]
# ### __Задача 2__:

# %% [markdown]
# Выведите 10 первых результатов и их близость по метрике BM25 по запросу **рождественские каникулы** на нашем корпусе  Quora question pairs.

# %%
QUERY2 = preprocess_query('рождественские каникулы')
bm25_scores = [bm25(QUERY2, doc) for doc in corpus]
output = sorted([(e,i) for i,e in enumerate(bm25_scores)], reverse = True)

# %%
for i in output[:5]:
    print(data[i[1]], i[0])
# Out:
# ['кто может рассказать некоторые обычаи о рождественском дне', 'какие рождественские традиции вы и ваша семья имеете на рождественский вечер и рождественский день', '1'] 25.32994807580993
# ['какие из ваших любимых рождественских традиций вы начали с вашей семьи', 'какие рождественские традиции вы и ваша семья имеете на рождественский вечер и рождественский день', '1'] 25.32994807580993
# ['что такое рождество, как на острове Рождества', 'что такое рождественский остров', '0'] 22.5243132808425
# ['почему есть рождественский остров', 'что такое рождественский остров', '0'] 22.5243132808425
# ['какой лучший рождественский подарок для вас', 'какой лучший рождественский подарок', '0'] 22.5243132808425

# %% [markdown]
# ### __Задача 3__:
#
# Посчитайте точность поиска при
# 1. BM25, b=0.75
# 2. BM15, b=0
# 3. BM11, b=1

# %%
b15 = 0
b11 = 1

# %%
def q_score_b(q, N, doc, len_doc, b):        #подсчёт score отдельного слова
    n = np.count_nonzero(result1[q])
    tf = len(re.findall(' '+q+' ', doc))
    idf = IDF(N, n)
    score = idf*((tf*(k+1))/(tf+k*(1-b+b*len_doc/avgdl)))
    return score

def bm25_b(query, doc, b) -> float:   #query подать уже нормализованную))
    doc_contents = doc.split(' ')
    len_doc = len(doc_contents)
    scores = []
    for q in query:
        try:
            scores.append(q_score_b(q, N, doc, len_doc, b))
        except KeyError:
            scores.append(0)
    return sum(scores)

# %%
bm25_scores_b15 = [bm25_b(QUERY2, doc, b15) for doc in corpus]

# %%
output_b15 = sorted([(e,i) for i,e in enumerate(bm25_scores_b15)], reverse = True)

# %%
for i in output_b15[:5]:
    print(data[i[1]], i[0])
# Out:
# ['кто может рассказать некоторые обычаи о рождественском дне', 'какие рождественские традиции вы и ваша семья имеете на рождественский вечер и рождественский день', '1'] 17.99038249822644
# ['какие из ваших любимых рождественских традиций вы начали с вашей семьи', 'какие рождественские традиции вы и ваша семья имеете на рождественский вечер и рождественский день', '1'] 17.99038249822644
# ['какой лучший рождественский подарок вы когда-либо давали', 'какой лучший рождественский подарок вы когда-либо получали', '0'] 11.993588332150962
# ['почему вы открываете подарки в канун Рождества и каково происхождение этой традиции?', 'какой лучший рождественский подарок вы когда-либо получали', '0'] 11.993588332150962
# ['что такое рождество, как на острове Рождества', 'что такое рождественский остров', '0'] 11.993588332150962

# %%
bm25_scores_b11 = [bm25_b(QUERY2, doc, b11) for doc in corpus]

# %%
output_b11 = sorted([(e,i) for i,e in enumerate(bm25_scores_b11)], reverse = True)
for i in output_b15[:5]:
    print(data[i[1]], i[0])
# Out:
# ['кто может рассказать некоторые обычаи о рождественском дне', 'какие рождественские традиции вы и ваша семья имеете на рождественский вечер и рождественский день', '1'] 17.99038249822644
# ['какие из ваших любимых рождественских традиций вы начали с вашей семьи', 'какие рождественские традиции вы и ваша семья имеете на рождественский вечер и рождественский день', '1'] 17.99038249822644
# ['какой лучший рождественский подарок вы когда-либо давали', 'какой лучший рождественский подарок вы когда-либо получали', '0'] 11.993588332150962
# ['почему вы открываете подарки в канун Рождества и каково происхождение этой традиции?', 'какой лучший рождественский подарок вы когда-либо получали', '0'] 11.993588332150962
# ['что такое рождество, как на острове Рождества', 'что такое рождественский остров', '0'] 11.993588332150962
